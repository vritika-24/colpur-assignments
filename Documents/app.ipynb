# %%
Name=input("enter you name:")
print("hello,", Name + "! Welcome to python.")
# Out:
# hello, vritika! Welcome to python.

# %%
print("hello",end=" ")
print("world")
# Out:
# hello world

# %%
print("2026","06","06",sep="-")
# Out:
# 2026-06-06

# %%
name="vritika"
age="20"
print("Name:",name,"Age:",age)
# Out:
# Name: vritika Age: 20
